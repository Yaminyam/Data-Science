# %% [markdown]
# <a href="https://colab.research.google.com/github/siontama/Data-Science/blob/master/Deep%20Learning%20with%20Python/8.5_introduction_to_gans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import keras
from keras import layers
import numpy as np

latent_dim = 32
height = 32
width = 32
channels = 3

generator_input = keras.Input(shape=(latent_dim,))

# 입력을 16 × 16 크기의 128개 채널을 가진 특성 맵으로 변환합니다
x = layers.Dense(128 * 16 * 16)(generator_input)
x = layers.LeakyReLU()(x)
x = layers.Reshape((16, 16, 128))(x)

# 합성곱 층을 추가합니다
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

# 32 × 32 크기로 업샘플링합니다
x = layers.Conv2DTranspose(256, 4, strides=2, padding='same')(x)
x = layers.LeakyReLU()(x)

# 합성곱 층을 더 추가합니다
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

# 32 × 32 크기의 1개 채널을 가진 특성 맵을 생성합니다
x = layers.Conv2D(channels, 7, activation='tanh', padding='same')(x)
generator = keras.models.Model(generator_input, x)
generator.summary()
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32768)             1081344
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 32768)             0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 256)       819456
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 32, 32, 256)       1048832
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 3)         37635
# =================================================================
# Total params: 6,264,579
# Trainable params: 6,264,579
# Non-trainable params: 0
# _________________________________________________________________

# %%
discriminator_input = layers.Input(shape=(height, width, channels))
x = layers.Conv2D(128, 3)(discriminator_input)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Flatten()(x)

# 드롭아웃 층을 넣는 것이 아주 중요합니다!
x = layers.Dropout(0.4)(x)

# 분류 층
x = layers.Dense(1, activation='sigmoid')(x)

discriminator = keras.models.Model(discriminator_input, x)
discriminator.summary()

# 옵티마이저에서 (값을 지정하여) 그래디언트 클리핑을 사용합니다
# 안정된 훈련을 위해서 학습률 감쇠를 사용합니다
discriminator_optimizer = keras.optimizers.RMSprop(lr=0.0008, clipvalue=1.0, decay=1e-8)
discriminator.compile(optimizer=discriminator_optimizer, loss='binary_crossentropy')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 30, 30, 128)       3584
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 14, 14, 128)       262272
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 6, 6, 128)         262272
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 2, 2, 128)         262272
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 790,913
# Trainable params: 790,913
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 판별자의 가중치가 훈련되지 않도록 설정합니다(gan 모델에만 적용됩니다)
discriminator.trainable = False

gan_input = keras.Input(shape=(latent_dim,))
gan_output = discriminator(generator(gan_input))
gan = keras.models.Model(gan_input, gan_output)

gan_optimizer = keras.optimizers.RMSprop(lr=0.0004, clipvalue=1.0, decay=1e-8)
gan.compile(optimizer=gan_optimizer, loss='binary_crossentropy')

# %%
import os
from keras.preprocessing import image

# CIFAR10 데이터를 로드합니다
(x_train, y_train), (_, _) = keras.datasets.cifar10.load_data()

# 개구리 이미지를 선택합니다(클래스 6)
x_train = x_train[y_train.flatten() == 6]

# 데이터를 정규화합니다
x_train = x_train.reshape(
    (x_train.shape[0],) + (height, width, channels)).astype('float32') / 255.

iterations = 10000
batch_size = 20
save_dir = '/content/gdrive/My Drive/Colab Notebooks/datasets/gen_images/'
if not os.path.exists(save_dir):
    os.mkdir(save_dir)

# 훈련 반복 시작
start = 0
for step in range(iterations):
    # 잠재 공간에서 무작위로 포인트를 샘플링합니다
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

    # 가짜 이미지를 디코딩합니다
    generated_images = generator.predict(random_latent_vectors)

    # 진짜 이미지와 연결합니다
    stop = start + batch_size
    real_images = x_train[start: stop]
    combined_images = np.concatenate([generated_images, real_images])

    # 진짜와 가짜 이미지를 구분하여 레이블을 합칩니다
    labels = np.concatenate([np.ones((batch_size, 1)),
                             np.zeros((batch_size, 1))])
    # 레이블에 랜덤 노이즈를 추가합니다. 아주 중요합니다!
    labels += 0.05 * np.random.random(labels.shape)

    # discriminator를 훈련합니다
    d_loss = discriminator.train_on_batch(combined_images, labels)

    # 잠재 공간에서 무작위로 포인트를 샘플링합니다
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

    # 모두 “진짜 이미지"라고 레이블을 만듭니다
    misleading_targets = np.zeros((batch_size, 1))

    # generator를 훈련합니다(gan 모델에서 discriminator의 가중치는 동결됩니다)
    a_loss = gan.train_on_batch(random_latent_vectors, misleading_targets)
    
    start += batch_size
    if start > len(x_train) - batch_size:
      start = 0

    # 중간 중간 저장하고 그래프를 그립니다
    if step % 100 == 0:
        # 모델 가중치를 저장합니다
        gan.save_weights('gan.h5')

        # 측정 지표를 출력합니다
        print('스텝 %s에서 판별자 손실: %s' % (step, d_loss))
        print('스텝 %s에서 적대적 손실: %s' % (step, a_loss))

        # 생성된 이미지 하나를 저장합니다
        img = image.array_to_img(generated_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir, 'generated_frog' + str(step) + '.png'))

        # 비교를 위해 진짜 이미지 하나를 저장합니다
        img = image.array_to_img(real_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir, 'real_frog' + str(step) + '.png'))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 9s 0us/step
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# 스텝 0에서 판별자 손실: 0.6946939
# 스텝 0에서 적대적 손실: 0.6558298
# 스텝 100에서 판별자 손실: 0.75776374
# 스텝 100에서 적대적 손실: 1.0386379
# 스텝 200에서 판별자 손실: 0.66274273
# 스텝 200에서 적대적 손실: 1.0225804
# 스텝 300에서 판별자 손실: 0.69901
# 스텝 300에서 적대적 손실: 0.7760757
# 스텝 400에서 판별자 손실: 0.69486654
# 스텝 400에서 적대적 손실: 0.74575764
# 스텝 500에서 판별자 손실: 0.7080484
# 스텝 500에서 적대적 손실: 0.79895985
# 스텝 600에서 판별자 손실: 0.69057095
# 스텝 600에서 적대적 손실: 0.72599334
# 스텝 700에서 판별자 손실: 0.69808024
# 스텝 700에서 적대적 손실: 0.7291502
# 스텝 800에서 판별자 손실: 0.69724864
# 스텝 800에서 적대적 손실: 0.76889545
# 스텝 900에서 판별자 손실: 0.70067245
# 스텝 900에서 적대적 손실: 0.7313746
# 스텝 1000에서 판별자 손실: 0.68558484
# 스텝 1000에서 적대적 손실: 0.72322166
# 스텝 1100에서 판별자 손실: 0.69283324
# 스텝 1100에서 적대적 손실: 0.745226
# 스텝 1200에서 판별자 손실: 0.69135654
# 스텝 1200에서 적대적 손실: 0.7553698
# 스텝 1300에서 판별자 손실: 0.6914337
# 스텝 1300에서 적대적 손실: 0.7540278
# 스텝 1400에서 판별자 손실: 0.70738643
# 스텝 1400에서 적대적 손실: 0.7526987
# 스텝 1500에서 판별자 손실: 0.6909242
# 스텝 1500에서 적대적 손실: 0.7507386
# 스텝 1600에서 판별자 손실: 0.710189
# 스텝 1600에서 적대적 손실: 0.80935895
# 스텝 1700에서 판별자 손실: 0.6892114
# 스텝 1700에서 적대적 손실: 0.75382614
# 스텝 1800에서 판별자 손실: 0.6808217
# 스텝 1800에서 적대적 손실: 0.7688119
# 스텝 1900에서 판별자 손실: 0.72128046
# 스텝 1900에서 적대적 손실: 0.7956692
# 스텝 2000에서 판별자 손실: 0.69699705
# 스텝 2000에서 적대적 손실: 0.77919346
# 스텝 2100에서 판별자 손실: 0.71029055
# 스텝 2100에서 적대적 손실: 0.7454697
# 스텝 2200에서 판별자 손실: 0.6943796
# 스텝 2200에서 적대적 손실: 0.77353793
# 스텝 2300에서 판별자 손실: 0.6979199
# 스텝 2300에서 적대적 손실: 0.7969031
# 스텝 2400에서 판별자 손실: 0.68656534
# 스텝 2400에서 적대적 손실: 0.7286081
# 스텝 2500에서 판별자 손실: 0.7060171
# 스텝 2500에서 적대적 손실: 0.7685996
# 스텝 2600에서 판별자 손실: 0.7014366
# 스텝 2600에서 적대적 손실: 0.7574793
# 스텝 2700에서 판별자 손실: 0.70237386
# 스텝 2700에서 적대적 손실: 0.73371553
# 스텝 2800에서 판별자 손실: 0.6912284
# 스텝 2800에서 적대적 손실: 0.7513591
# 스텝 2900에서 판별자 손실: 0.70445615
# 스텝 2900에서 적대적 손실: 0.76356226
# 스텝 3000에서 판별자 손실: 0.7091753
# 스텝 3000에서 적대적 손실: 0.751839
# 스텝 3100에서 판별자 손실: 0.67577267
# 스텝 3100에서 적대적 손실: 0.69547874
# 스텝 3200에서 판별자 손실: 0.69551915
# 스텝 3200에서 적대적 손실: 0.76408476
# 스텝 3300에서 판별자 손실: 0.7000986
# 스텝 3300에서 적대적 손실: 0.71979
# 스텝 3400에서 판별자 손실: 0.68672293
# 스텝 3400에서 적대적 손실: 0.72985244
# 스텝 3500에서 판별자 손실: 0.6882268
# 스텝 3500에서 적대적 손실: 0.7302221
# 스텝 3600에서 판별자 손실: 0.6993736
# 스텝 3600에서 적대적 손실: 0.77364266
# 스텝 3700에서 판별자 손실: 0.6843382
# 스텝 3700에서 적대적 손실: 0.7607725
# 스텝 3800에서 판별자 손실: 0.68831336
# 스텝 3800에서 적대적 손실: 0.9326084
# 스텝 3900에서 판별자 손실: 0.70199096
# 스텝 3900에서 적대적 손실: 0.75394773
# 스텝 4000에서 판별자 손실: 0.6871784
# 스텝 4000에서 적대적 손실: 0.72114503
# 스텝 4100에서 판별자 손실: 0.68162286
# 스텝 4100에서 적대적 손실: 0.735109
# 스텝 4200에서 판별자 손실: 0.70358914
# 스텝 4200에서 적대적 손실: 0.7690444
# 스텝 4300에서 판별자 손실: 0.6878034
# 스텝 4300에서 적대적 손실: 0.7421642
# 스텝 4400에서 판별자 손실: 0.70170754
# 스텝 4400에서 적대적 손실: 0.7737758
# 스텝 4500에서 판별자 손실: 0.69496053
# 스텝 4500에서 적대적 손실: 0.7584366
# 스텝 4600에서 판별자 손실: 0.69601166
# 스텝 4600에서 적대적 손실: 0.75210184
# 스텝 4700에서 판별자 손실: 0.68921196
# 스텝 4700에서 적대적 손실: 0.7527088
# 스텝 4800에서 판별자 손실: 0.6835109
# 스텝 4800에서 적대적 손실: 0.78144276
# 스텝 4900에서 판별자 손실: 0.7046993
# 스텝 4900에서 적대적 손실: 0.7264043
# 스텝 5000에서 판별자 손실: 0.6898763
# 스텝 5000에서 적대적 손실: 0.8217522
# 스텝 5100에서 판별자 손실: 0.6976159
# 스텝 5100에서 적대적 손실: 0.7530796
# 스텝 5200에서 판별자 손실: 0.6726432
# 스텝 5200에서 적대적 손실: 0.7862837
# 스텝 5300에서 판별자 손실: 0.69116336
# 스텝 5300에서 적대적 손실: 0.7325907
# 스텝 5400에서 판별자 손실: 0.6942698
# 스텝 5400에서 적대적 손실: 0.80667317
# 스텝 5500에서 판별자 손실: 0.68850774
# 스텝 5500에서 적대적 손실: 0.83927906
# 스텝 5600에서 판별자 손실: 0.70043224
# 스텝 5600에서 적대적 손실: 0.7317315
# 스텝 5700에서 판별자 손실: 0.6970098
# 스텝 5700에서 적대적 손실: 0.8494897
# 스텝 5800에서 판별자 손실: 0.7190297
# 스텝 5800에서 적대적 손실: 0.7386614
# 스텝 5900에서 판별자 손실: 0.6940459
# 스텝 5900에서 적대적 손실: 0.7087528
# 스텝 6000에서 판별자 손실: 0.708795
# 스텝 6000에서 적대적 손실: 0.77420694
# 스텝 6100에서 판별자 손실: 0.69375896
# 스텝 6100에서 적대적 손실: 0.75200576
# 스텝 6200에서 판별자 손실: 0.6949007
# 스텝 6200에서 적대적 손실: 0.6983442
# 스텝 6300에서 판별자 손실: 0.6871516
# 스텝 6300에서 적대적 손실: 0.7652557
# 스텝 6400에서 판별자 손실: 0.789932
# 스텝 6400에서 적대적 손실: 0.85072404
# 스텝 6500에서 판별자 손실: 0.67869484
# 스텝 6500에서 적대적 손실: 0.8406631
# 스텝 6600에서 판별자 손실: 0.70579255
# 스텝 6600에서 적대적 손실: 0.68993866
# 스텝 6700에서 판별자 손실: 0.8048379
# 스텝 6700에서 적대적 손실: 0.7834612
# 스텝 6800에서 판별자 손실: 0.67901844
# 스텝 6800에서 적대적 손실: 0.7639064
# 스텝 6900에서 판별자 손실: 0.7013658
# 스텝 6900에서 적대적 손실: 0.79382867
# 스텝 7000에서 판별자 손실: 0.6800097
# 스텝 7000에서 적대적 손실: 0.7502412
# 스텝 7100에서 판별자 손실: 0.69099325
# 스텝 7100에서 적대적 손실: 0.8217842
# 스텝 7200에서 판별자 손실: 0.6976007
# 스텝 7200에서 적대적 손실: 0.79259616
# 스텝 7300에서 판별자 손실: 0.6800421
# 스텝 7300에서 적대적 손실: 0.8002488
# 스텝 7400에서 판별자 손실: 0.79891354
# 스텝 7400에서 적대적 손실: 1.1508399
# 스텝 7500에서 판별자 손실: 0.6942787
# 스텝 7500에서 적대적 손실: 0.7274678
# 스텝 7600에서 판별자 손실: 0.7105661
# 스텝 7600에서 적대적 손실: 0.9375755
# 스텝 7700에서 판별자 손실: 0.780505
# 스텝 7700에서 적대적 손실: 1.1932219
# 스텝 7800에서 판별자 손실: 0.6675125
# 스텝 7800에서 적대적 손실: 0.8285972
# 스텝 7900에서 판별자 손실: 0.6932762
# 스텝 7900에서 적대적 손실: 0.7848838
# 스텝 8000에서 판별자 손실: 0.65614974
# 스텝 8000에서 적대적 손실: 0.8017918
# 스텝 8100에서 판별자 손실: 0.73551065
# 스텝 8100에서 적대적 손실: 0.8941511
# 스텝 8200에서 판별자 손실: 0.7126238
# 스텝 8200에서 적대적 손실: 0.77429545
# 스텝 8300에서 판별자 손실: 0.6536515
# 스텝 8300에서 적대적 손실: 0.8555376
# 스텝 8400에서 판별자 손실: 0.69313365
# 스텝 8400에서 적대적 손실: 0.7660135
# 스텝 8500에서 판별자 손실: 0.62988454
# 스텝 8500에서 적대적 손실: 0.74426126
# 스텝 8600에서 판별자 손실: 0.70273006
# 스텝 8600에서 적대적 손실: 0.7628775
# 스텝 8700에서 판별자 손실: 0.67167336
# 스텝 8700에서 적대적 손실: 0.72968125
# 스텝 8800에서 판별자 손실: 0.69270575
# 스텝 8800에서 적대적 손실: 0.82265204
# 스텝 8900에서 판별자 손실: 0.68543893
# 스텝 8900에서 적대적 손실: 0.7717645
# 스텝 9000에서 판별자 손실: 0.6760912
# 스텝 9000에서 적대적 손실: 0.8655292
# 스텝 9100에서 판별자 손실: 0.6854447
# 스텝 9100에서 적대적 손실: 0.7692643
# 스텝 9200에서 판별자 손실: 0.6895884
# 스텝 9200에서 적대적 손실: 1.1169745
# 스텝 9300에서 판별자 손실: 0.6756719
# 스텝 9300에서 적대적 손실: 0.76436675
# 스텝 9400에서 판별자 손실: 0.7283442
# 스텝 9400에서 적대적 손실: 0.79004776
# 스텝 9500에서 판별자 손실: 0.63947856
# 스텝 9500에서 적대적 손실: 0.939563
# 스텝 9600에서 판별자 손실: 0.67007357
# 스텝 9600에서 적대적 손실: 0.76198757
# 스텝 9700에서 판별자 손실: 0.7788391
# 스텝 9700에서 적대적 손실: 0.99654406
# 스텝 9800에서 판별자 손실: 0.6859475
# 스텝 9800에서 적대적 손실: 0.8722437
# 스텝 9900에서 판별자 손실: 0.6705674
# 스텝 9900에서 적대적 손실: 0.7055413

# %%
import matplotlib.pyplot as plt

# %%
random_latent_vectores = np.random.normal(size=(10, latent_dim))

generated_images = generator.predict(random_latent_vectors)

for i in range(generated_images.shape[0]):
  img = image.array_to_img(generated_images[i] * 255., scale=False)
  plt.figure()
  plt.imshow(img)
  
plt.show()
