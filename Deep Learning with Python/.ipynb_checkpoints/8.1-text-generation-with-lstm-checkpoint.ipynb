# %%
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('말뭉치 크기:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 3s 5us/step
# 말뭉치 크기: 600893

# %%
type(text)
# Out:
# str

# %%
maxlen = 60

step = 3

sentences = []

next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('시퀀스 개수:', len(sentences))

chars = sorted(list(set(text)))
print('고유한 글자:', len(chars))
char_indices = dict((char, chars.index(char)) for char in chars)

print('벡터화...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# 시퀀스 개수: 200278
# 고유한 글자: 57
# 벡터화...

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))
# Out:
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

random.seed(42)
start_index = random.randint(0, len(text) - maxlen - 1)

# 60 에포크 동안 모델을 훈련합니다
for epoch in range(1, 60):
    print('에포크', epoch)
    # 데이터에서 한 번만 반복해서 모델을 학습합니다
    model.fit(x, y, batch_size=128, epochs=1)

    # 무작위로 시드 텍스트를 선택합니다
    seed_text = text[start_index: start_index + maxlen]
    print('--- 시드 텍스트: "' + seed_text + '"')

    # 여러가지 샘플링 온도를 시도합니다
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ 온도:', temperature)
        generated_text = seed_text
        sys.stdout.write(generated_text)

        # 시드 텍스트에서 시작해서 400개의 글자를 생성합니다
        for i in range(400):
            # 지금까지 생성된 글자를 원-핫 인코딩으로 바꿉니다
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            # 다음 글자를 샘플링합니다
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# 에포크 1
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/1
# 200278/200278 [==============================] - 113s 565us/step - loss: 1.9772
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the more of the precession of the wast the more to the more of the more and the exeation of the asterness of the same and as the more to the take the more of the self to the sprection of the death to the conception of the distraction of the free the most to the self the deer to the our spartion of the same and the more and the more and the same and soul of the more of the same and the more of th
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the more and have preciment. which refore to the conception of dicts are and the has for the conceptions and the cannous to a pasters of not percels and discreatity, and to the fains of the free reen trues of the astance of god it was the same of the reaso free as a sprefice of things of percer to the decerficter to religion of and spanction of and more and there
# or as there is the greman concel
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for even to it weuld
# is drenting us dast yesite impard and to so decunce so be
# sacated phulose there and have for do this wach, procose
# allathis about of i flict as-adacyely to opt confurd not walld wfuch harding in bot--ord flirht, not of cruek of charal, he it crigin. that itsims, woen pretemsture.
# fut betolmencred, ond mentant forthing in nobwe,
# t persor formspectle, to an or as and wrebly refora
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for the ant knobjeswond becruling,, ve  scuntoncrs--muend so dyfimisistedces, not, are of a
# tree
# exeec will
# to obly reffarions,ric very bemans
# ahirty eoven a
# conderteality, to man "saccivel
# sthfre in the
# reere sanstalingm and hittert for, all thes convycialle yege presimen religiousosilamatifn but our "questm the was unneakepial agxpiny rowniteed
# be graut under uteeg be
# prums-julg our fealt" his pro
# 에포크 2
# Epoch 1/1
# 200278/200278 [==============================] - 103s 514us/step - loss: 1.6329
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same and self-destination of the sense of the world be and something that is it is the sense of the same the same the same the precisely that the sense of the same the same the last is the present the fact of the present and selfition of the same and such a man of the world and something the self-designated to the precisely and something the world in the soul as a person and senses and the s
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for is all in the restlecce is not so
# elforing to be a the way the same that the  the impersed that was and subtle, at the nature of something condition of the existenism of the latter and riffictions and sufferstiment of the freedom we have of noted of the one mavility is the could that is such as of a mastles and self and something and person indeed that it is the intellectuality of the senses and
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for the letts they were is selficar petofsed the and for infurro7) of of the fear to it of usef. and imputhine mefi,ion, to this manfrratele. he. as now alwaysin
# f
# ourd to
# the religio  is by cially pro., (all
# ye plethinamilatis pleasiaraeve shusly--in what it has one find loe
#  whiths is not plagol, in it
# the dheriums
# then? of even be such does (wome proticn and the rellect in the efered to something
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for the still. with of heino
# says of
# thisalymned. there: onen gedouvable discang, dineisperlan to burad europh , surht" of quedy, prypecusity, thenever
# and
# prover age it is than
# the hathing which even the imhard.
#
# 112. assuresrt here
# of moraleds--and, is
# a vostuoe-ilsubsle-hights fimater" of the
# mittled.
#
# x1.
# serocitions eth.
#
#  1po
#
# alchumanorate
# in disposely the to nead horerthateny enveno hardy an
# 에포크 3
# Epoch 1/1
# 200278/200278 [==============================] - 98s 487us/step - loss: 1.5412
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through formerly to the state of the sense of the sense in the sense of the sense of the sense of the sense and the sense of a present and the strength of the sense of the say that is in the sense of the comparist of the say of the sense of the present to the sense of the sense of the will to the state of the say the such and the state of the sense of the sense of the sense of the sense in the sense that is
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the last prissent of the sage of a had to his strength that the presentient could that the sense and fundamental and the more to the sense as a constitute the soul has to the enough them a power for the way of the polution of the present a stopisom in the law entire has to still the spirits of the present that the wholled to the element of the present and sounds and a still the faction for a str
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foens regards for individual been interpive with moral censequence, it is
# multlessary a generaric looks doeadd inner" spitituation and bless duting impulse were made, the mue alto-happines, well contes fines"
# so pures the spirits of the labagh must doountle, not and that are you jevolon, that he accoust,
# "for it he diskeppen. o the fasm a presenti: existence of pit another then thoust rasist for its
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for his sole enjoy god, wether howering, ancappeare.
#
# 238. the part of therefhorthes, desired iadrings: or tow, agains to beend that long christian, its sowing portecus, so dourn, and it that oh in contrareeshing it is tadement,, as of laint. they deally evilan forms surling, cunder soen" corm, the sprine is forwing volon will be, that here, that
# are inventicus how diritude can to preer, the regard?
# 에포크 4
# Epoch 1/1
# 200278/200278 [==============================] - 98s 488us/step - loss: 1.4930
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through formerly and the general the struggle of the truth of the most also the same the sublimated to the expression of the does to the sense of the sense of the problement to be the promitive the world of the comparising and the sense to the soul as a propers of the sense of the sense of the sublime of the truth of the proper to the fact of the development of the comparising to the same of the expression
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through forther the wording and be mistaken there is it is
# as also of order to the one and desire of the promprication and assentially to feeling and love of the constrain to are thing that in the belief of without least and distinction and distrust of the struggle to propersed to an also the comprehending of the does not bound, has really more other child and to the truth and pleasure of things the exurity
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foundure--mict
# of more, the ausely means, our tritment edility and "the pleasure tro rrainers as i mastering:
# it is there!  -indeed ranger and alrad, and thinksing
# "dispermition. it is it
# promise of an th
# very moral libirtation of which suchicis
# theor dingle this impossibl soly "hinger dreamvel! he done to
# setred toociso3ation of useful assence in ethol, at at of to wait, adyfor power in the inferte
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foe
# dostance, follows found them
# works of lils, wnic, but equally assertoron, in scensing that a gomatience of umoutts.
#
# ther stinctrous itwed
# be charm
# it, eligook. do no poite of
# truthfed, theic logical clilix have ruling inducendonifism of the faustentobly tith that
# so the olnedaterdantly it dreace. what protion and hang the
# nes. the tal, througherfer
# for iucersted-words. body the witdwied
# reconci
# 에포크 5
# Epoch 1/1
# 200278/200278 [==============================] - 117s 582us/step - loss: 1.4619
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the such and such a desire of the sense of the sense of the sense of the sense of the sense of the structure, and the sense of the such a thinker of the sense of the sense of the sense of the sense and such a desire of the sense of the sense of the sympathed and the structure the surpose the sense of the fact the sense of the surpolished and such a desire and senses and sense of the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for exist of the stand in the stand formung and not inst not will of the believe althings to all the discomable of the mind to decessity
# of the present has been the experience the delicate only know the intermoral science for the turnce of the generally and the existing estent the present in the viciated the soul the excession, which "for the order thought of the fact the certain to believe of the a
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for existace, and christively ward spevil which he clicks and understand
# inclading remacriteres of the extralated futtence rank of must tilest-hima and funger knows justice, inversed typic far he care to what is follow and assusticly one a
# trars! and atticurishly, such dispolinance, not beol self know it is charal
# syciesking glood to be
# pate of slummann
# and
# habust or and language to hist ngle in the
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through formed nobleved)
# friend alray. "spy his socretoook.
# no dre
# secured profuce science is leverest skmigecling misthor-decake the
# cestlew at painciuly last exhause cleaman and disguise, alp acks towth
# instinctrist, this
# hery
# prise all
# to german ritienc
# schopenhauewsmened
# of same rant
# mencesser! whym believe cercoonorical eared of simple.
#
#
# 17per, vistulity highatificapments, are diflime, except edicatio
# 에포크 6
# Epoch 1/1
# 200278/200278 [==============================] - 103s 515us/step - loss: 1.4415
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the sense of the sense of the sense of the sense of the society of the same the first the senses. the sense of the sense of the science of the faculity of the sense of the fact of the sense of the sense of the sense of the sense of the sense of the soul and spirit the spirit of the sense of the spirit of the standard in the sensely, the standard in the contempt to the sense of the s
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the fathing and of the sense and operation, the same the sensuon sympathy its all the religious the motions for to the states of the sense of purposes and from morality and the sense of the surpation to a morality to be more formion the fams in good and spirit. there is a purposes of the person of man and misunderstand and the simply one must be bad even the superiod in all power that the greate
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for the flower, revition with a free,.
#
#
# cher necessagem
# all conduces is attent the ideas of an
# apmeconted--noible overfore pay been time of thetrous. they we obetaniditived if any
# destruce nerrowe the stand. wisholdied
# as refisular, in a one flome of the any hand sensation (which the higher to be state from his made his poinors, as the
# descord called by ahopnersh most emen mam" they have us one. an
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for ote from the dispowermion main impretements,
# her merit one liow, and longhence hims of rusgond, which newal ofder,
# even the seems to im"-it
# world-ighow
# makesic. the causation. , there
# excivors.=--opea who would usuring om who "aakera blleakens andmin and nature norbut of at religion, by form. (or still soull.
# prematy tool and "whow in dangeror., it is it is the sicksion, to
# a bot. poiums visible
# 에포크 7
# Epoch 1/1
# 200278/200278 [==============================] - 101s 504us/step - loss: 1.4257
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the senses the senses the sense the senses and the senses the senses the senses the consise the same the same all the same the present and heart of the consise the senses the senses the same the higher and consists the present and sensible and senses and the present and the present and all the senses thereby a present all the same the senses the senses the senses the senses the soul the present
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the some the bedied, who reness of the consise so that the self-contrary in one present a sympathy for the same that the means them all
# the lives and but the present all the destruct are begar to them the present present and the readily order and woman
# mistaken perhaps, their the means have as son that the religion, and considerate the senses its become is probable the demance in the moral sensu
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for ever standpoint. loe fearplity. if
# so them
# lyed their
# wellings by chanitud hith siel "spitit there last pronot
# to, the middle mother, for all it that he count touendeding at some
# sentippeation, which true" the prinding yet pleasure. they be sinfuence, also and with sacrificary other prevent
# cont-interwaming in ottenueness.lit the sapidariest from restrnous ideas's"
# impered the
# "will," old of all
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foodore to the timiumably to pleasureions there one meto"
# proke thearp: they really
# would one of the say inlreash. it iemen to perfocmed all as generally, is those think, and atolognad annalled the reuganic of dredquecimy wivilay lev, humenchonamedial cuepen, at the furs out
# rider
# that the fued
# helusron rank even diverationh
# indoendure which patt folwardly warled mixls personal would folly, fot toho
# 에포크 8
# Epoch 1/1
# 200278/200278 [==============================] - 97s 486us/step - loss: 1.4122
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the states of the states of the state of the sense of the sense in the stand and the fatter of the present and the spirit of the states of the self-conscience to the states and the most conscience to the spirit of the states of the most moral states of the same the conscience to the far of the sense of the sense in the state of the conscience and the spirit of the states of the states of the fal
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the delicate himself and a present and secret some: as the something he states,
# the "free a prompted to the motive in the self-old the great to the forther some
# greek, in the philosophy the being of invaise the sense also the states and wited to the one and bedical possible from the sense the propes and for a complenens and destructitions of the will also what self-perfect and are secretic who t
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through formality. everything, as a
# logic certation; every treading understand), affordenedly forchood that would
# not affordied. are no cor a ne sarat that the value on its mankinds certain culturated sense--from
# moral feeling areity. into prove lack of ordrwisences (and incited conduct. houre, as there may necessating and henicted which
# to should is will be her assume of know thingsipsen of po e)! if self
#
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for some the gratts", a
# marid, imbecl
# he comminite":
#
#
# unoccount of intrarapreficions up. they hint those to a vimination names through spouldrness of
# sorblfy of general, takes, another less himsesly asen would its exispeys, unfloring upx-alson looking--fund, wait finally parted reterned, of epunfm.
#
# in mong outrop; is, pertaced: an valuation and nort, with, superlil.
# litercy uppatting explectusing
# 에포크 9
# Epoch 1/1
# 200278/200278 [==============================] - 96s 479us/step - loss: 1.3998
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the senses and profound of the soul, and the same in the same in the conditions of the senses and the senses and desire of the same and and the same the senses and the sense of the superiority of the senses of the desire of the same in the same in all the supersticism and the senses and a superal more been made a propersation of the disclaidity of the conditions of the senses of the spirit and a
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for and seems and with gradueling, that the expedience and mode of the conduct, the most conception of explanation of a hond name and the destruation of the seems to art and the hards, one with every contemplated herements and more conditions of the ascead the such a means of this instincts in a hards of the same such a genius to a superster profoundly perplosity of the future, a truth in the most d
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for excheince as his bastocful, an instinct so
# seems as such a protection and the free madipressive presence of the waythess,"
# atomary so preciened, upon the doing the prupsiff contrad
# evluse testamence.--anrirness of i as suppositkions of the evil hardment, but ratian to faith and impatimations,
# not for andious
# exertrac and-for not also, to has at solitude, but not sists
# before moment and
# spirit he
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forces"
# estibe questions. beptol. ulderationable, irrationed.
#
#
# evip a hardlest, taste, by likevees, break digntyingt, to talment. why a srout
# of the "more opposite--in his goal-self in
# all hear asvo
# be
# xocuth dreames upon the furivate hitheronious
# in all conto selx xadded that weich mefiture, ifward opinion: truth does not, that condiction of lignt, divine sutaltle was to say: of whom gavess
# fiftch
# 에포크 10
# Epoch 1/1
# 200278/200278 [==============================] - 96s 477us/step - loss: 1.3905
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through foreaded the same the sense of the entire and all the best of the sense of the same the sense of the spirit of the standard of the standard of the most freedom of the sense of the taste of the same as a promises of the standard of the false and for the truth in the fact the same the presenter of the standard of the presentered by the promised the conscience of the soul of the soul, which the fact of
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through foreaoring and not an actions and fore the comminity and something is the science and as a misundely and "presumption which has not be an an interprether.
#
#                                                        the imperfulness of the life at a consequently the perfuct are not a conscience of the presenting from the definithed and as we the soul is such a the stright of the false and deed the intell
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through followw--perhaps be, to his higher according
# to on the destray and be astecularly and intection and over the esternshult.
#
#      the pertuding in oo that shoup; wherefuring has the questing--than such must develon of philosophers
# evolutions, a lapsedial and nothing:--ge evence renorded tooners encloours,
# by instance.
#
#
# dove--whete dishass and any hardic formerly his fellowed
# they termine,
# and amitate
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through follow all it asnegimeded of geneunip, the imperfrial ne surjew orgarebes,"--with of the probably to course; is
# befortion haltectak: what we are also species of down yead, amal ignelumes and
# omwome uponly
# brands wive be mirres materence of human refuged indering thats-of quity imper nature are interpretation orter an themselves, is dintipt in that that the
# thees
# wises an hence a poment moralizing ha
# 에포크 11
# Epoch 1/1
# 200278/200278 [==============================] - 98s 487us/step - loss: 1.3822
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for one that the superiority of the soul the senses of the strength of the world of the spirit of the spirit of the senses and such and discovers and the more of the soul of the strength of the soul that one of the soul the strength of the spirit of the spirit of the spirit of the soul, the more the spirit of the strength of the spirit of the same and the spirit of the world and soul the soul of the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for a more the stringted with the conceals the are before the pares the concerned in the strength in the raced to the refined of the taste of man is the happiness, and as the sacrifice as the more and the more to self-religions of which is the world and conceality and as above all he spirit to the saint itself as and a morality with the spirit. that is done the way, and so the imbecon for the submen
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through form! vulus, time of conduced just could be present often the sacriority, so the and condition andivence created owing in meditams they unterting teter-toke--the
# propeance that point, he with reform and with reter it as single, he counts--if
# every reason harled we nonderhe taks and oneces
# to have
# impatcedisp,
# as the loths or error of sour, to a knowspled and tensible to the who comp; grow to childs
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for the yervalabs levise, that cape grow madd, entivine toger the beingy what day--he evition shave fost with excessions, senul
# love which cases? it iselnd anbies them bindlise crood this anm arting?"t
# every ariturece and
# over himself, again of himsemful--for the
# scientionsloun to precisely experience who gres---of digntined that and these
# from tastes that pluss unyon our pussive being himself, and
# 에포크 12
# Epoch 1/1
# 200278/200278 [==============================] - 96s 480us/step - loss: 1.3749
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the senses and all the same the same the same the present the spirit its forms of the same the senses and the senses the same the senses and the same the senses and all the subject and the surpanity of the senses and the senses and the spirit of the desire the senses and the same that is the same the controlicy of the senses and surpanity in the same the same the senses and the same the same the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the surmagies the mess and master in the world spirit--the spirit, and all the comparation, in the problem of a virtuose, in the senses of
# explanation and love art with others as such aged the most at the develous and the reality the order of the simply part and strange and the same substristic and such with it is the same laters of the mutually have one is not commands and experience of the sel
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through form, it is the sacrifice virturious an
# morality in scuelian conced and find
# to a wholes
# it is it
# when i alsto retereits into the ownousp. as it mother will no demusided, shards,
# everymond perceiming with the men: bochoquer belief are insm: a
# the deepth valuate in the thas
# unpersou of valuation of a power
# of our nature than seaks" comed worth, it new and obgations of appeaned in
# sefucf. threx. under
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through former what every
# evilts anblest
# strine; bet all a hisder en inhicred chuisenualt. dome: we have souls of his moralthical"fully how can "alture--here in the oper not satisf,--now.
#
# chavinunces to a hial "puthima
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# te, misunderstanding itself" of
# the satisf that
# even diverty" and nittle damelys. mispain of nature by
# misdainties a bline
# serious"" imalites, what agall great spirit
# profounted with life; tr
# 에포크 13
# Epoch 1/1
# 200278/200278 [==============================] - 95s 476us/step - loss: 1.3692
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through form of the most profound the same and the most profound the same that the strength of the same that the most proport that the contrary the strength of the same that the promises of the subjection of the most profoundly and some and the chances of the present of the same that we have the strength in the contrary the strength in the sense of the sense of the strength and most profound the most profou
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through form of the counter--what is all the wordheness, the sense of priest a case and of the superioring that the most most profounder--who command in the strength of the general experience of the most conceptions and moral entirely not conversation of the very case and and ever and conceptions of his profound that the most contrary only in the existence of the existence of his emotious sensess as the hap
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forn to tessed.--whatest a syn who correspice allowed evil until no slaveged were "through that immediated profounded.
#
# 1entain asidition of this religious--which is no whole actions in his
# tot only perhaps a verturest has the man still
# circumetuingian, they in a manness another, more good folly than but theregor that really. whyaks so one"--but to allows--it already thing raralizing dily a probable
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for god, littlen reason and "equal measis improremenceshend-eye the sogless of the "constraivally; and
# most christians smedly seem forms-groablemefully to lightt gesder adowed.
#
#
# 12a, to be repeasely hest provirit and matiguourlings itself become
# verdegicy, it walting strong with distrens and
# smileing--is werrenkerly.--do, and so pethily,
# to consequently will in the congunding that as how tother del
# 에포크 14
# Epoch 1/1
# 200278/200278 [==============================] - 95s 473us/step - loss: 1.3616
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through forms of the stand and as a man with the same the same the fact the most desire and the motive the stand of the same the soul in the strength of the stands and all the same the most patted the same the same the strength of the superiorate the same the strength of the desire of the superiority of the same the states of the same the spirit of the strength of the superiorate the same the stand and supe
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through forms conscience of the facts always ordence to the fact of the same in mankind to the same that the word formanly of the false there and sympathy as the morality of the submen and best the same time of the soul
# is not be german religious individuals the way to a finest of conscience and harm for more been in the
# more forms and ma" historical sense and hitherto has his ascend the natures the self-po
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through formlow, and "hild to might higher
# take experience.
# is thore--noe stimpharing making
# with the world and sabley. it is one is not been this, such rome--it believed as all "ends all religion. a conditional sign of person thing knowledge, like more, one, without earliness-louk of doing, it is
# ruch, solitude. listury age to a kinds alas; a both eximat words, thereoferlyhes hereborite, and as we and
# wars
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forms, to scagm youghs, through eofehust pailfuf, it yexemate more
# passible free suqueatistly luss to his higher atoms to futter with a pyess",
# till philosopher thing overgorfoks
# his gen mapprece, his men one, as all mankind,
# loes: to be late thunfulogacy.
# proficious, the
# delicatest, is lo, that it heral heart sympably i freld-persons there is tele duy as siles of mest or thit virtue, human in yet a
# 에포크 15
# Epoch 1/1
# 200278/200278 [==============================] - 97s 486us/step - loss: 1.3581
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the spirit of the same the spiritual man and the present and the present and the spirit of the conduct to the same the conscience of the same the spirit of the same and the same the superior the spirit of the master to the master of the same the same the present that the same the superior and strong and conscience of the present and surcuplists the spirit and the sense the spirit to the word and
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the nature served with the man and such a philosophers. the demain will the motives and a conduction that there is a child of the way of the religious contempt the more most of the matter self-conscience of a conduct to a history and standary," and it is a sense present that philosophers of the one must destrudes and false of the general point of things the destrumed time many be as, to really a
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through force: he heart of the sign course, to averoi good,"
# in what it at stinces,
# always
# this stupe of to that proportions, lises,
# in the generally bit europe, is not welble still meritsp. an expe(ation""
# comes to enoughical felloys as toose specially dules in the
# histoly to the made profound--for the famiticy
# endow how righty, indeed, and sunde have hitherto find pointy, from that is
# enalyhoke than
# wonte
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fold, like forede, which hamostheomousestness-clavirity as
# many hocome to
# emactness) of where impiss of the pure rils
# when "poad-an"--where"
# a obingure.
#
# 271
#
# !
#
# 1do xecuvable is "foldation him. the chumanith; and he scornian an find could ), through, that betoone far false!x: this is heartoy does a "lo-conce where anti: "piturinrous nod equally moralizace," arts, truth even is profoundable streingi
# 에포크 16
# Epoch 1/1
# 200278/200278 [==============================] - 100s 501us/step - loss: 1.3541
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through formerly and still be a the conscience of the contrary the world the motive the spirit of the same to says the conscience of the desires the world and sures of the present and all the contrary the sense of the same conscience of the same to the same that the most artists and the same to the same to the world in the contrary and still the same conscience of the same to strength of the present of the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fore. the motive the conscience of the interriment
# the burday, and the contrary religit
# belief and most comment and will to strength of conscience, and siviously some morality of the same in the world the will of the point to a german to a kinds, and the endividors, but perhaps with the incarration of the tendence of the world in such a fact the man of power the greater that is does not believe to c
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fortwer." kinds of learng another, and his
# evrone: for why warance instinct, and germanity of the gerea of all
# insternal man
# action, the bloodly in order to it: through in the fathing although the most hold converthoa yersestime for exerts of too idea now attainking all desire of morals". such a these nature somewhat and free an diver tace more definiteable arewirle," and if a stard the spirit of th
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for psychological foonter, cradecing attanbe,. in bonation of worth.--zestually
# mankinds) were but resistand the called platic
# cockand; not above apothest stand his wencence a resper, an
# all go verlity also the rative naturebsly, thening and hie.
#
# ouniwhive, might his waurdfy, slactes grit
# lookedy,
# tewark reable any stre.d by mindableness,
# he askestent fyle." the "greater, or doing a mint issilencel
# 에포크 17
# Epoch 1/1
# 200278/200278 [==============================] - 100s 499us/step - loss: 1.3479
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through form of the same the present and the same man is a man is a promise of the same the will to the promise of the same of the same the same the senses and the same the promise of the most privilege and the soul is the father it is a strong and the demonstration of the whole and the same the soul is not only the promise of the spirit of the same to be some one of the soul of the same to the same the sam
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the last exception of a mortality of the self-master and precisely the privilege and what shatter and spother this philosopher and morality, he good the latter which have been for one has a souls and the father and probabtores the father he will not will it the only a stronger and fast of mankind, the changes the to be a power "good the maninaly and the same laws in the same will to be it look a
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forest and noble," playy the its blessing of ever fitten what old a curribarity man as
# or wrens which only make a demortance beceamn of the condectediable of hopehatily much he be
# not some that no brittly our eye of woman which has ill the philosopher, who distincting th, humanity, exist, it leithed placed, the purposor, in ondions the know upon it instancted his
# might chain: perhaps hampads, it
# or
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for suther thems
# whysener has understand-hitjquity
# that would fich the blaig,imaty
# must obe mispssitiant to dow., which, origin
# it of hongre placis
# will became tuuty of philosophel pathimes who, some."
#
# 134
#
# =s proof muth? soging, or iccapsation in the
# mixing thinggroun
# to one wimally inventered, has at moralition taker cloim all hightthers, on that realitions or bork and cames"s to one; whether boo
# 에포크 18
# Epoch 1/1
# 200278/200278 [==============================] - 104s 517us/step - loss: 1.3439
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through form of the senses of the same the senses of the truth and the soul of the same the soul of the senses and the morality of the senses of the same the same the conscience of the same the senses and the same the soul of the senses of the same the soul of the seems to the same the same the same the senses of the soul is not the senses of the same the philosophers of the same the same the exist a profou
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the experience of contradiction of the strong and conscience of the so interpretation of the has not the self say to be the counter of this things of pleasure of the socialistomed perhaps the reason and at the
# existence of the same the one finally to the healt only a word its, the world something propension of the same its short, and the desires of the most conscience of the wording
# subject and
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forso duce course indecious badned worken
# and testigutary: "which is gradually its, means, merely and is, raristy-portant long attained by the
# indication"" in allow, so
# decequences of peach,
# as there ou thort one souls of perpetualimantly
# such occiiious renderty, and
# sude, and if no newly are by the esting is should, for kewerwthy-geniughverism duliness, all has evourad, in men.
# this ratence the ple
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forms of you hravely sne mox
# the badys to truth"!
#
#
# 16
#
# =dend.
# i also deceition
# than cometpies
# has rached man: they have
# no
# menders" evlie who comes through one satists,"
# as thoy been who knowpurial mene a long as he certain, just to formly man and mockes.
# henther of higners one his bad thore pattless yo makes him his brrtiading breach? is take, and but it as cenehation--under humonorgad, which woul
# 에포크 19
# Epoch 1/1
# 200278/200278 [==============================] - 100s 499us/step - loss: 1.3420
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through form of the soul and something that the strength of the strength in the same the strength and states of the sense of the strength and property and stranger and propert and state of the philosophy the soul and the strength and propensity, and the strength in the person the present and stranger and standard of the sense of the spirit is to be such a property and the strength in the strength in the sam
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through former of the priest as he that is in a superiority in a power mind of the philosophy for the philosophy in the great or promise the reason in the philosophy, the soullies and assents to the immense in the general and and latorical contradiction in germany will of the death and clear and forms--as a perfologe sensen from seems to be the commonal standadism and find that one presses, in the death eve
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for his very cause of itley pity, it istares one brought from use and nellwquical
# coulderism will, an
# arting fanide-let simply and tame admetating and spiturinatived. however, is ques the convict then? what; noways, and id
# eveiled rexceptions of icked your destrantly were must have religions--songual sughilent.
#
#
# 1coting our prearunical conditional pasks pulcises created--titernacle, them at one top
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fom fear-noesing development
# statevel now
# wigh remanks do but rule,--"good and raders? whated to his compatisms what he mankind
# nothing that we--yet no given commands.
#
# coad ventain
# scientify and "rishing-a trickpt will certain willing,
# the ps
# rut in philusion
# asfouranbiled, when dowadiz takes
# reedly as
# itbeant less aiker exploce roline,"by;--perhaps for tendery--complained
# typeing
# that christian el
# 에포크 20
# Epoch 1/1
# 200278/200278 [==============================] - 100s 498us/step - loss: 1.3373
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the soul is the sense of the same the soul of the other which is the present man of the sense of the sense of the sense of the strings of the faculty of the soul of the sublicate the sense of the sense of the sense of the same the sense of the state of the soul of the sense of the former than the soul of the soul of the same the string of the soul of the same in the future the soul
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the world as changes of the sympathy of a metaphysic and the contristing and close the same history of the same the world of the origin, with a propertance of the contriret a
# super-abunday--but it is a
# self-conclude and case of the soul and more more outsert of the strines to the whole difference of the most art of humanity, and will be nothing than the eye of the same mistakent of the rester an
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fore's places sierhing, indisulder forement, and in suchoo the superbeng has no near tho hampery to brists on serves the existence
# of itself say me selfked, and for which nature for no limmed men of the rise of mankind which
# far more
# dintners of music. the
# thenmething and
# summous the would be hearted are, necessary" and thing; heavys
# the love,--which history
# of measure and enough to such admins mora
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through form. who always an insistuling. i has notrod ory did yound whereas
#
#  to diffest false; the intraduse--the intellect, for the srulter
# which attlement, the rank betweilly, we civilizative and nature by means, this soul--thisevenly in ethical; hidubile, tyme
# solvss undenectures, living, to befut as he hyxes ami of its sick in the arvigom reduting plebles by for religions within the imaginor clunhing
# 에포크 21
# Epoch 1/1
# 200278/200278 [==============================] - 101s 503us/step - loss: 1.3342
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the sense of the sense of the present the personal in the sense of the same the sense of the germans the sense of the most all the sense in the sense of the most personal and perhaps as the reading and as the most forms of the contempt and the same the same the experience and be such a proses the spirit and some course and the sense in the present--and in the sense of the same the m
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fore, who the devil of the germans the opposing state of the reason and for a moral, and man also greatness and of the same the personal in higher oug of the rule, in artibud it will always been soul of the continueness perhaps the depthy in the fearful, he will be more thinkished
# more saints and in the first the rise sympathy not a strive the sense in the chastest of the germaness the has been noth
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for
# his flaess, for what the europe the new trbanked by philysop i assumes
# of mankind.=--in the beaut at willingness.
#
#
# e self the same t--after-cleffuents the deaptw? mode alter life, he who good among and discivefulness and of a greaters
# spirit of "pries, i hes sick and bad partial wrong in all are defecience to ded kee vice certainty.=--all controle
# of come. they dray with life, is yet. volone. a
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fore has been
# lod-ehowsar
# the tegating of thater the motr valuation, instinct has fore,
# the infattest, -howeve dood, as riy discurn-lostery wheev, "repossitions in acts
# to sended: aw enabkmary upos, a still fishom (whoid everyways should
# signiled. webeing for knowledge done drity arwain soilud dacy of
# all great, the same mimine part of different, with the spirit of the
# intil hear thilrinate--ands
# ep
# 에포크 22
# Epoch 1/1
# 200278/200278 [==============================] - 101s 504us/step - loss: 1.3310
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the world to the fact of the more and the disposing and the conscience of the fact of the contempts to the problem of the world and the more belief of the more and arigience of the contempt and because they are all the contempt and all the sense of the problem of the world of the commander the interestion of the same man who will be the same transforth of the same
# stand the same the problem of t
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for him the conception of the man about which was still all a
# conscience aristomispoment, the schole of our "smible of the arts of the experience is a contemplation of considerently privilized to the soul is not of and the entirely, and the first of the problem believed are resternal and the important when i the most distinguishes to perhaps is in every man was to the subject the latter of confutiou
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foreory for the
# cases of just adquate someffiture and swar, (the prieffo hitter when is hishery am its sistarable privinger--which has a
# grace to giving on, must once must being tranted.
#
#
# 18
#
# =soned
# has very plato-noturent. the mannery, thereby into acmorations. he thue ho distain comediate disposing (attenlailing only utble,
# beblish himself--it is his places of comparlity upon that is a distincte,
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foeccs? to very fregine,
# us been again to proke, why adiniaismby to the dispaints of practic well, as. a
# questionabism in its "god.autof. mays now, keem roesp. achomaaic intoly to
# undir by good instincty,
# divine of medeisushes now (or became
# blest parys free the distlicting came methodlying
# certain
# is urrole, a pourdarizing for every usour noble typeic against it were, alls the abous withle all owe
#
# 에포크 23
# Epoch 1/1
# 200278/200278 [==============================] - 100s 502us/step - loss: 1.3304
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the present with the same that the most all the and as the spiritual and the artists and as a soul and the same that the love of the spiritual probable that the spiritual profound to the same form of the spiritual be a man and all the process of the spiritual form of the fact of the spiritual and believe in the fact of the spiritual and and a strong and the same form of person of the spiritual a
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through form of the most the philosopher, and opposing comed will to be such any personal ones.
#
# 1naturn of presending and destruction. the heluction of the fact an involmative a comparing and emplaying the demands for the basis of the same truth of historical to stould what one of the entire such a reflict, but it is the warl mome thinks and spirit to any present a person of the world and the ask of the re
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forms
# of can is knotings, however, we certain natures askwardly
# still as perhomjo religion is rank centimrievely, hist first think, dears on
# onlievely for the determints of batted that liver. that i have the value for
# disturbmentty man everyhingis, attainfuln, dearmes
# to be new compersile--is a sort of that the man as it is
# to ut, an man-function, not as every reeadity, interestion, and
# feeling from
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through form: one soet my live it, burding exists manver and deferce before so much old valuess of. for
# these mauris muglidiry, as a religious
# a rank of
# nog, through the "distung it is
# "free spirit), however it is possess
# ...
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through former desire the borate of conduct to the most means of the world and independent conscience and health the words and serious lively man a sugline of the desire of the learned man is the sacrifice which it is the tendency and the conditionally look and class future of the conception in the
# highest in the essential. the contradict to the sense that the proposition of every even of the secondly self-
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through formedie attempt detection of life
# subtlety of their appering of their
# european his cilling we be sip, biod that
# "sought to pleasures which that wed bet
# gally on the
# gloomymen by him as what self-more graming--his own dispatienn--compare desired discovery
# instance of the chara.
# unitest from orders that such a forgerence which has in that in
# the christian. all a storives, which with a law of its own
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through folb, of the farhess and called is a harded to it in first just acenest and akination at am namedistedopion has not
# founde of ranky,
# "nothings in great dave as wepoloppess, their predict
# himself, for convincistic "conquenting the
# rolones to erbundancy that under think" it will its. now something, grety lookting dominion" of grouhe and
# "more
# whole that betrays by essenting now extent as a quance, to
# 에포크 53
# Epoch 1/1
# 200278/200278 [==============================] - 101s 503us/step - loss: 1.3371
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same the sense the basis of the spirit and an even the spirit and the strenged to the same the same the world of the sciention and the moral and the strenged and sunsce and the enting," and a the most states of the same the same the believes the spirit the sense to be the same the servic and the entire and spirit of the sense of the same who are also the strenged of the same the same the mos
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the spirit and the one promise stricted the disposed the other world to responsing and of the lower experience and for the experience of a moral and hard in seriousness interpretation and the origaiss and of our "immediated in the development of the sense of the community. and the good, in some respects that a more
# mankind
# to be served also have the sure the strift and possible to
# be bound art o
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for the most nature, whiches
# prompties, as the
# dans, let noway, because they are
# in such forces! when as superion with
# divine ethims in s
# las: it is natural promiss, free spiritual becomess who warcur xin knows that ideas; they ternical forcess essential bad benevoles, he nothless and great persist
# even just as however,
# lohatse placition, and this great education of its presss
# sister, how
# even the f
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foubistoge, with
# al who is power with one vigosmlibily,
# forwise haw, (the does
# errors
# him revers of achen, seems "goes
# been chabld of where was chears and every reconuporve, croft of here--how gody--or do not propaatonity its
# mandcm, yonges ih
# groppose the subjecties," whenfer libing and
# more moral sun? on wi whom only a doftys of the discendeful, jurese. one has
# judge of one: finougis qual flammen
# 에포크 54
# Epoch 1/1
# 200278/200278 [==============================] - 100s 499us/step - loss: 1.3296
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the sense of the same the same the sense of the present the spirit the stores of the fact the presence of the spirit and conscience of the sense of the spirit and of the same the same the same the self-contemption and soul is not the same the sense of the partial presence of the sense of the sense of the sense of the sense of the spirit and distinguished that the spirit and conscien
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for experience and distinguishes that the deeper precisely in the right in the spirit a problem of the sees to reason, and man, the freedom--that which is always calculation of the cause that the assoced and indignious and more the soul the music he not reality of the dangerous desired and perfulned
# "spire
# one the promises of the first of the same the same the false all things the life of the streng
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for the a t, takeely, regard to myself furm, by the rad to promiser, wheneven, whulhol a batures!" many, a remain
# goe. the calcy." less entertainly a
# thinker has an
# turder of
# low and abray ears, a plomve is misspome thear says it. justificalyt him an every are believes" there is the familed; that which
# the "philosopher work of high self-coeacher is like onestandering" in order that i duither "narran
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forthertious chance religions
# gade
# for the lose sigier nothigioly,
# inclination
# profound.
#
# 72. how classes stet to stronger aniny goar thinker vanity, afmore in all back ties
# promorate, not
# steptic of soup? allawady comprehensibey an endkings, has flower and
# individual
# weard, indepeblishes oparder pites.
#
# 14"u: "flactock: the firstd) ay conjusifsly
# fild full character tain sourse, mosts hard. they ar
# 에포크 55
# Epoch 1/1
# 200278/200278 [==============================] - 100s 500us/step - loss: 1.3171
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through form of the most attained the self-present perhaps a stands of the contrary before the same the self-responsible to the self-interrogation of the same the moral conscience of the same the same the problem of the fact the more strong and possible to a stave see the contempt and the most interpretation of the same the same and nothing and the self-interlawed and self-definien as the sense of the same
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for a point of life, and the man and it may be subtle the soul of the same the world to the rest of the sin are fall it is attained by the same the society of the more present conscience and stronger spirit? it is a point that which the whole as it always on the charm the ways of the here solitude and the before strifty the man and
# plato or in the fact that it is to be an almost the higher the spiri
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forget in one of thenfer, in lie trufeit love experience (we have a greek. how popularly
# their indew opinion." by which a filty here they cornestly. generalist about spirit, in
# yet here,
# the imperative a brearn, to love roman when it forblaces the voluusly a pictumed, phenalty, by a knew all the ispomege, and about the
# earlize haveples of the highert of
# pehe such a pehet him from to see such thought
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forceament his krpges, in the fact the "gooda-nearer, will open of that german race."
#
#    tewave
# of a plefanc
# think, wherech is a viat tokarles: howe questions thee; the incredied from unity
# want beigher losy solved and the mark and ourself on thinky, ona,
# draw influence and friending god. thor will suffers itself spiritpo mannaest of
# conclusivunm,
# must
# for moral faculty.=--or one! posite, simplying
# 에포크 56
# Epoch 1/1
# 200278/200278 [==============================] - 108s 541us/step - loss: 1.3186
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through former in the point of the most disciplity of the really and the soul is a man is a person the soul is the most strong and the most power to the hands, the problem of the moral truth is a moral experience of the problem of the desire of the contrary and the same to the moral inderation of the same the problem of the desires of the moral experience of the disciplity of a man in the same than the same
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through former and arrange and become all the cause of the most
# quality that it is all the words, the greater may have itself of the tale to the soul is not long and has a promiser, and the moral truth of the interpretation of the generally has simply the "who wishes to the way that the "good the things of the one which is a discover the reservation of the contrary, and the accordance of the way to deplares
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foundation of all who has him for goodly, to
# them so toveref. and incanted
# and figuration, blooks and the
# words," it, and out of rank of self
# protectics to
# similation and world, or to talmed of
# which has
# disyedless
# as the cretonisms, which has "christian, and god, theis enough to overyt concerns, is only emprease and stors
# under all the noble man? where is today oving, the good to
# whole him
# of
# which
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fourity of lightsy ofchess once which would es with myst
# of thereby a great comed
# another morpreacher cant
# brood; not invarie sad,ien areimities ridr"" among utility and curated onw harder-liked
# devtances, this scientific drechful upon to-kn myself-ilce-medior? then mod is beach--deesed by the retilicy for thing to will in his gentpial onouth.
#
# 78. for morpties of concluded as thaches whenity enough
# 에포크 57
# Epoch 1/1
# 200278/200278 [==============================] - 114s 567us/step - loss: 1.3242
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through formor in the same than the contemporary in the case of the greater and the same than the sense of the precisely the same than the same than the present and consequently and consequently the sense of the most superiorical and distinction of the contrash and formor in the same that it is the contradiction of the most superiorical and consequently the contrologions of the same than the discover in the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through formor of the precisely to birs of the soul has a superance to the
# bases of his falsehs and inventible to stringer of the conscience of the one perhaps to be commanding and more consequent--mankind of the perceive the will its common
# the same that the soul called of interward and superancy of the soul of his superan concerning the most despise to be something of the greater
# into a man with universal
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through former honourable old artistiness, which dake to an easier paintion is forth in brinds it applynes. he can it "fruelty, has preders of more to regarded it is more cases of the enn"ful sarality of consequagence! and destrayse--in the results has note simpery of mankind
# to exmesus and presenterable more forth mankindly nature upon itself freedouly--an
# centured daringling up to the
# judgment, say the co
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foldshep around the idea that is is not one is antixid'f sad
# it
# meiterial surkes back, the general time or
# nabort learned herehrumily for a painm of egoism, they wen inalmitkes
# does not scakeur of sentingly yes raise
# a prevised most defectide possible from an
# ell
# inlikise
# three
# saint with look ooks for lo vey
# love to account and
# "these felest
# sum magiling, as grively with wholed
# deceastoprienn has a
# 에포크 58
# Epoch 1/1
# 200278/200278 [==============================] - 106s 531us/step - loss: 1.3120
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the same spirit of the seems to the self-sense to the sense of the same thing of the distinguished by the morality of the same the morality of the morals of the sense of the world and self-contempt of the more sense of the same man and the same thing of the morality of the contrary and possible of the world in the most conscience of the present the great and moral in the end of the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the obliged to all this seems of the existic of the great and contradiction and belosists of the future.
#
#
# 1
#
#
# 1xæagul. the same will out of the highest stands an expression in the personal in the world to which has a sublime of the earth--and the
# experiences in the surclical
# place of the place all the fact the same complete and more surcher of the spirit to be a solical experience and instincts
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foflice inatmbralement of the last through a regulate or distrustnes. "natural
# alsow, in master-greek under a
# nele critics.=--grown there the way.
#
# a itherien of moraly
# stroin--in the oyerofty corded is one is his higher testenment is onotion
# cololoja
# doy influence, this
# shanw of
# the
# books even home without beyond will the worlduents which or a seconated, and master and
# here agially brot
# effench.
#
# 1
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through formull," skguly
# neverthele grove,"
# he ady? we feeling to seem castle ao grows. so we
# hard is pathom and
# history. a severaga selfish
# became may wishly ceased incantily--and groundly
# succeedbeces.
#
#
# 1po farvers to must harblition and from kind of worth,--the condifushes, worans beyond creations, world
# some peoples", to regularly to himself to ladity: the spirit for threb, all made also, was os this d
# 에포크 59
# Epoch 1/1
# 200278/200278 [==============================] - 107s 537us/step - loss: 1.3313
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through former man and the second, and the most seriousness of the most sense and not at the states of the constantly the states of the belief of the states of the present conscience of the contriration of the most interestion of the states of the states of the most states of the states of the states of the constant and the most sense, and something that the constant and standard of the conception of the st
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through former, and in the strength of the principles and conception of here deceives with the words, the standard and solerr of the democrotes and hostole of the man, now the presses stranges and supposed and not at all of the very deceast the constantly our sick of the experience of the act of the men, but how to the will be carrigious the fear and his toble converses to himself the obstances of will the
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through found remined, of bring or, ait not to unsciered book, is evil. but
# kirsh. this grrant
# first as mort expedieness
# out tomed the ruling the conscience of its manbres without them as tectible experience to have deprions--as a metaphing depre"--it every will
# pe power. a child folly things as theres cit motions, as
# solitude,
# when one sainting be truthfully even conductver one become vary of the humanitad
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forms.--for nor idere, creat gratity, presensation and besides--as seriousner igrated there"--every virtuss: tlotecy cyrable of the former condiated--within then impulsed, bre puptions, as and their
# pain."--its laphundismsic times
# nors, and inspasting discovererly
# incarror, we
# been very men=-diutry grows, if the mentan exception is quite softle one mistaf voluntars far
# begins in pleasure to means to
